# %%
import numpy as np
import pandas as pd

# %%
#missing_values = ["Null", "?", "--","","FALSE",".","-","nan","False","R","r"]
pd_file2 = pd.read_csv('/Users/Lisa/Documents/BigData/homework2/gridresult.csv')

# %%
pd_file2.count()
# Out:
# Unnamed: 0     414661
# caldt          414661
# crsp_fundno    414660
# mtna           412928
# mret           413366
# mnav           413428
# Unnamed: 6         10
# Unnamed: 7          8
# Unnamed: 8          6
# Unnamed: 9          6
# Unnamed: 10         4
# dtype: int64

# %%
pd_file.loc[:, ['crsp_fundno']].head()
# Out:
#    crsp_fundno
# 0          105
# 1          105
# 2          105
# 3          105
# 4          105

# %%
funds = np.unique(pd_file.loc[:, ['crsp_fundno']])

# %%
single_unique = []
double_unique = []

crsp_list = list(pd_file['crsp_fundno'])
my_len = len(crsp_list)
for i in range(0,my_len):
    if crsp_list[i] not in single_unique:
        single_unique.append(crsp_list[i])
    elif crsp_list[i] not in double_unique:
        double_unique.append(crsp_list[i])

# %%
len(double_unique)
# Out:
# 47520

# %%
for f in funds:
    temp = pd_file[pd_file['crsp_fundno']==f] 
    if len(temp)>1:
        temp2 = pd_file[pd_file['crsp_fundno']==f].interpolate()
        pd_file[pd_file['crsp_fundno']==f] = temp2
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-87628f26e138> in <module>()
#       3     if len(temp)>1:
#       4         temp2 = pd_file[pd_file['crsp_fundno']==f].interpolate()
# ----> 5         pd_file[pd_file['crsp_fundno']==f] = temp2
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3111             self._setitem_frame(key, value)
#    3112         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3113             self._setitem_array(key, value)
#    3114         else:
#    3115             # set column
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    3129             indexer = key.nonzero()[0]
#    3130             self._check_setitem_copy()
# -> 3131             self.loc._setitem_with_indexer(indexer, value)
# ...

# %%
# Out:
#             caldt  crsp_fundno       mtna      mret       mnav
# 0        20100129          105  25.300000 -0.054960   7.050000
# 1        20100226          105 -99.000000  0.035461   7.450000
# 2        20100331          105 -57.466667  0.075342   7.850000
# 3        20100430          105 -15.933333  0.022930   8.030000
# 4        20100528          105  25.600000 -0.079701   7.390000
# 5        20100630          105  25.100000 -0.048714   7.343333
# 6        20100730          105  24.600000  0.078236   7.296667
# 7        20100831          105  24.100000 -0.043536   7.250000
# 8        20100930          105  26.700000 -0.001322   8.070000
# 9        20101029          105 -99.000000  0.040892   8.400000
# 10       20101130          105 -99.000000  0.008333   8.470000
# 11       20101231          105  28.300000  0.069658   9.060000
# 12       20110131          105  28.400000  0.005519   9.186667
# 13       20110228          105  28.300000  0.017563   9.313333
# ...
